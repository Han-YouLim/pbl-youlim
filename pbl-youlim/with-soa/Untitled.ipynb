# %%
import numpy as np
import pandas as pd
import re
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

import warnings

RANDOM_SEED = 42
TEST_SPLIT = 0.2

warnings.filterwarnings(action='ignore')

DATA_IN_PATH = '../../../big_data_sample/pbl/with_soa/'
DF_INPUT_DATA = 'train_clean.csv'
DF_TEST_DATA = 'test_clean.csv'
DF_TEST_LABEL = 'test_clean_label.csv'

# %%
from sklearn.model_selection import train_test_split
train_data = pd.read_csv(DATA_IN_PATH+ DF_INPUT_DATA, encoding='cp949',  names=['comments', 'label'], header=None)
test_data = pd.read_csv(DATA_IN_PATH+ DF_TEST_DATA, encoding= 'cp949', names=['comments'],header=None)
test_label = pd.read_csv(DATA_IN_PATH+ DF_TEST_LABEL, encoding= 'cp949', names=['label'],header=None)
print(test_label)
# Out:
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 8240      0
# 8241      0
# 8242      0
# 8243      0
# 8244      0
#
# [8245 rows x 1 columns]

# %%
X_train = list(train_data['comments'])
y_train = list(train_data['label'])
y_test = list(train_data['label'])
y_test_np = np.array(y_test)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vec_cv = CountVectorizer(analyzer = "word", max_features = 5000) 

X_cv = vec_cv.fit_transform(X_train)

X_cv.shape
# Out:
# (8245, 5000)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vec_tf = TfidfVectorizer(min_df = 0.0, analyzer = 'char', sublinear_tf=True, 
    ngram_range = (1,3), max_features=5000)


X_tf= vec_tf.fit_transform(X_train)
Y_train = np.array(y_train)


X_tf.shape
# Out:
# (8245, 5000)

# %%
vec_tf.get_feature_names()
# Out:
# [' ',
#  " '",
#  " 'ㄷ",
#  " 'ㄹ",
#  " 'ㅁ",
#  " 'ㅂ",
#  " 'ㅅ",
#  " 'ㅆ",
#  " 'ㅇ",
#  " 'ㅈ",
#  " 'ㅉ",
#  " 'ㅋ",
#  " 'ㅎ",
#  " 'ㅠ",
#  " 'ㅡ",
#  " '가",
#  " '각",
#  " '간",
#  " '갈",
#  " '감",
#  " '갑",
#  " '강",
#  " '갖",
#  " '같",
#  " '개",
#  " '걍",
#  " '거",
#  " '걱",
#  " '건",
#  " '걸",
#  " '검",
#  " '게",
#  " '결",
#  " '경",
#  " '계",
#  " '고",
#  " '곧",
#  " '곳",
#  " '공",
#  " '과",
#  " '관",
#  " '광",
#  " '괜",
#  " '교",
#  " '구",
#  " '국",
#  " '군",
#  " '궁",
#  " '권",
#  " '귀",
#  " '규",
#  " '그",
#  " '극",
#  " '근",
#  " '글",
#  " '금",
#  " '급",
#  " '기",
#  " '길",
#  " '김",
#  " '까",
#  " '깔",
#  " '깜",
#  " '깨",
#  " '꺼",
#  " '께",
#  " '꼬",
#  " '꼭",
#  " '꼴",
#  " '꾸",
#  " '끄",
#  " '끝",
#  " '끼",
#  " '나",
#  " '난",
#  " '날",
#  " '남",
#  " '낫",
#  " '낮",
#  " '내",
#  " '냐",
#  " '너",
#  " '넌",
#  " '넘",
#  " '넣",
#  " '네",
#  " '녀",
#  " '년",
#  " '노",
#  " '논",
#  " '놀",
#  " '놈",
#  " '높",
#  " '놓",
#  " '뇌",
#  " '누",
#  " '눈",
#  " '뉴",
#  " '느",
#  " '늘",
#  " '능",
#  " '늦",
#  " '니",
#  " '님",
#  " '다",
#  " '단",
#  " '달",
#  " '담",
#  " '답",
#  " '당",
#  " '대",
#  " '댓",
#  " '더",
#  " '데",
#  " '도",
#  " '독",
#  " '돈",
#  " '돌",
#  " '동",
#  " '돼",
#  " '되",
#  " '두",
#  " '둘",
#  " '뒤",
#  " '뒷",
#  " '드",
#  " '든",
#  " '듣",
#  " '들",
#  " '듯",
#  " '등",
#  " '디",
#  " '따",
#  " '딱",
#  " '딸",
#  " '때",
#  " '떠",
#  " '떨",
#  " '또",
#  " '똑",
#  " '똥",
#  " '뛰",
#  " '뜨",
#  " '라",
#  " '랑",
#  " '래",
#  " '러",
#  " '레",
#  " '로",
#  " '를",
#  " '리",
#  " '마",
#  " '막",
#  " '만",
#  " '많",
#  " '말",
#  " '맘",
#  " '맛",
#  " '망",
#  " '맞",
#  " '맡",
#  " '매",
#  " '머",
#  " '먹",
#  " '먼",
#  " '멀",
#  " '멋",
#  " '멍",
#  " '메",
#  " '며",
#  " '면",
#  " '명",
#  " '몇",
#  " '모",
#  " '목",
#  " '몰",
#  " '몸",
#  " '못",
#  " '무",
#  " '묵",
#  " '문",
#  " '물",
#  " '뭐",
#  " '뭔",
#  " '뭘",
#  " '미",
#  " '민",
#  " '믿",
#  " '밀",
#  " '밉",
#  " '바",
#  " '박",
#  " '밖",
#  " '반",
#  " '받",
#  " '발",
#  " '밤",
#  " '밥",
#  " '방",
#  " '배",
#  " '백",
#  " '버",
#  " '번",
#  " '벌",
#  " '범",
#  " '법",
#  " '베",
#  " '변",
#  " '별",
#  " '병",
#  " '보",
#  " '복",
#  " '본",
#  " '볼",
#  " '뵙",
#  " '부",
#  " '북",
#  " '분",
#  " '불",
#  " '붙",
#  " '븅",
#  " '브",
#  " '비",
#  " '빠",
#  " '빡",
#  " '빨",
#  " '빼",
#  " '뽑",
#  " '뿐",
#  " '사",
#  " '산",
#  " '살",
#  " '삼",
#  " '상",
#  " '새",
#  " '색",
#  " '생",
#  " '서",
#  " '선",
#  " '설",
#  " '성",
#  " '세",
#  " '섹",
#  " '소",
#  " '속",
#  " '손",
#  " '솔",
#  " '수",
#  " '숙",
#  " '순",
#  " '술",
#  " '쉬",
#  " '스",
#  " '승",
#  " '시",
#  " '식",
#  " '신",
#  " '실",
#  " '싫",
#  " '심",
#  " '싶",
#  " '싸",
#  " '써",
#  " '쓰",
#  " '쓸",
#  " '씨",
#  " '씩",
#  " '씹",
#  " '아",
#  " '악",
#  " '안",
#  " '앉",
#  " '않",
#  " '알",
#  " '암",
#  " '앞",
#  " '애",
#  " '야",
#  " '약",
#  " '양",
#  " '얘",
#  " '어",
#  " '억",
#  " '언",
#  " '얼",
#  " '엄",
#  " '업",
#  " '없",
#  " '에",
#  " '엑",
#  " '엔",
#  " '여",
#  " '역",
#  " '연",
#  " '열",
#  " '영",
#  " '옆",
#  " '예",
#  " '오",
#  " '온",
#  " '올",
#  " '옷",
#  " '와",
#  " '완",
#  " '왜",
#  " '외",
#  " '요",
#  " '욕",
#  " '용",
#  " '우",
#  " '운",
#  " '울",
#  " '웃",
#  " '원",
#  " '월",
#  " '위",
#  " '유",
#  " '으",
#  " '을",
#  " '음",
#  " '응",
#  " '의",
#  " '이",
#  " '인",
#  " '일",
#  " '읽",
#  " '임",
#  " '입",
#  " '있",
#  " '자",
#  " '작",
#  " '잔",
#  " '잖",
#  " '잘",
#  " '잠",
#  " '잡",
#  " '장",
#  " '재",
#  " '저",
#  " '적",
#  " '전",
#  " '절",
#  " '점",
#  " '접",
#  " '정",
#  " '제",
#  " '조",
#  " '존",
#  " '졸",
#  " '좀",
#  " '좃",
#  " '종",
#  " '좆",
#  " '좋",
#  " '좌",
#  " '죄",
#  " '죠",
#  " '주",
#  " '죽",
#  " '준",
#  " '줄",
#  " '중",
#  " '즐",
#  " '증",
#  " '지",
#  " '직",
#  " '진",
#  " '질",
#  " '집",
#  " '짓",
#  " '징",
#  " '짜",
#  " '짤",
#  " '짱",
#  " '쪽",
#  " '쯤",
#  " '찌",
#  " '찍",
#  " '차",
#  " '착",
#  " '참",
#  " '창",
#  " '찾",
#  " '채",
#  " '책",
#  " '챙",
#  " '처",
#  " '척",
#  " '천",
#  " '철",
#  " '청",
#  " '체",
#  " '초",
#  " '총",
#  " '최",
#  " '추",
#  " '축",
#  " '출",
#  " '충",
#  " '취",
#  " '측",
#  " '층",
#  " '치",
#  " '친",
#  " '침",
#  " '카",
#  " '칼",
#  " '커",
#  " '컨",
#  " '컴",
#  " '코",
#  " '쿵",
#  " '크",
#  " '클",
#  " '키",
#  " '타",
#  " '탄",
#  " '탈",
#  " '태",
#  " '터",
#  " '테",
#  " '토",
#  " '통",
#  " '퇴",
#  " '투",
#  " '트",
#  " '특",
#  " '틀",
#  " '티",
#  " '팀",
#  " '파",
#  " '판",
#  " '팔",
#  " '패",
#  " '팩",
#  " '퍼",
#  " '페",
#  " '편",
#  " '평",
#  " '폐",
#  " '포",
#  " '폭",
#  " '표",
#  " '풀",
#  " '풍",
#  " '프",
#  " '피",
#  " '필",
#  " '하",
#  " '학",
#  " '한",
#  " '할",
#  " '함",
#  " '합",
#  " '항",
#  " '해",
#  " '행",
#  " '허",
#  " '헬",
#  " '현",
#  " '협",
#  " '호",
#  " '혹",
#  " '혼",
#  " '홍",
#  " '화",
#  " '확",
#  " '환",
#  " '활",
#  " '회",
#  " '효",
#  " '후",
#  " '훨",
#  " '휴",
#  " '히",
#  " '힘",
#  "'",
#  "',",
#  "', ",
#  "']",
#  "'ㄷ",
#  "'ㄷㄷ",
#  "'ㄹ",
#  "'ㄹㅇ",
#  "'ㅁ",
#  "'ㅁㅈ",
#  "'ㅂ",
#  "'ㅂㅅ",
#  "'ㅅ",
#  "'ㅅㅂ",
#  "'ㅆ",
#  "'ㅇ",
#  "'ㅇㅂ",
#  "'ㅇㅇ",
#  "'ㅇㅈ",
#  "'ㅈ",
#  "'ㅈ'",
#  "'ㅈㄴ",
#  "'ㅈㄹ",
#  "'ㅉ",
#  "'ㅉㅉ",
#  "'ㅋ",
#  "'ㅋ'",
#  "'ㅋㅋ",
#  "'ㅎ",
#  "'ㅎㅎ",
#  "'ㅠ",
#  "'ㅡ",
#  "'가",
#  "'가게",
#  "'가격",
#  "'가능",
#  "'가다",
#  "'가르",
#  "'가면",
#  "'가보",
#  "'가요",
#  "'가장",
#  "'가져",
#  "'가족",
#  "'가지",
#  "'각",
#  "'간",
#  "'갈",
#  "'갈다",
#  "'감",
#  "'감'",
#  "'감사",
#  "'갑",
#  "'갑자",
#  "'강",
#  "'강사",
#  "'갖",
#  "'갖다",
#  "'같",
#  "'같다",
#  "'같이",
#  "'개",
#  "'개'",
#  "'개돼",
#  "'개발",
#  "'개새",
#  "'개인",
#  "'걍",
#  "'걍'",
#  "'거",
#  "'거'",
#  "'거기",
#  "'거리",
#  "'거야",
#  "'거의",
#  "'거지",
#  "'걱",
#  "'걱정",
#  "'건",
#  "'건'",
#  "'건가",
#  "'걸",
#  "'걸'",
#  "'걸다",
#  "'걸리",
#  "'검",
#  "'게",
#  "'게'",
#  "'게이",
#  "'겠",
#  "'겠다",
#  "'결",
#  "'결과",
#  "'결국",
#  "'결제",
#  "'결혼",
#  "'경",
#  "'경'",
#  "'경비",
#  "'경우",
#  "'경쟁",
#  "'경찰",
#  "'계",
#  "'계산",
#  "'계속",
#  "'계시",
#  "'계약",
#  "'계획",
#  "'고",
#  "'고'",
#  "'고객",
#  "'고기",
#  "'고맙",
#  "'곧",
#  "'곧'",
#  "'곳",
#  "'곳'",
#  "'공",
#  "'공'",
#  "'공부",
#  "'공장",
#  "'공항",
#  "'과",
#  "'과'",
#  "'과제",
#  "'관",
#  "'관련",
#  "'관리",
#  "'관심",
#  "'광",
#  "'광고",
#  "'괜",
#  "'괜찮",
#  "'교",
#  "'교수",
#  "'교육",
#  "'구",
#  "'구'",
#  "'국",
#  "'국가",
#  "'국민",
#  "'군",
#  "'굳",
#  "'굳이",
#  "'궁",
#  "'권",
#  "'권'",
#  "'귀",
#  "'규",
#  "'그",
#  "'그'",
#  "'그거",
#  "'그건",
#  "'그걸",
#  "'그것",
#  "'그게",
#  "'그날",
#  "'그냥",
#  "'그때",
#  "'그래",
#  "'그러",
#  "'그런",
#  "'그렇",
#  "'그룹",
#  "'그리",
#  "'그만",
#  "'극",
#  "'근",
#  "'근거",
#  "'근데",
#  "'글",
#  "'글'",
#  "'금",
#  "'급",
#  "'급'",
#  "'급하",
#  "'기",
#  "'기'",
#  "'기간",
#  "'기능",
#  "'기다",
#  "'기분",
#  "'기사",
#  "'기술",
#  "'기안",
#  "'기억",
#  "'기업",
#  "'기자",
#  "'길",
#  "'김",
#  "'김'",
#  "'김치",
#  "'까",
#  "'까지",
#  "'깔",
#  "'깔다",
#  "'깜",
#  "'깨",
#  "'깨물",
#  "'꺼",
#  "'꺼지",
#  "'께",
#  "'께'",
#  "'께서",
#  "'꼬",
#  "'꼭",
#  "'꼭'",
#  "'꼴",
#  "'꼴리",
#  "'꽃",
#  "'꾸",
#  "'끄",
#  "'끄다",
#  "'끝",
#  "'끝나",
#  "'끝내",
#  "'끼",
#  "'끼'",
#  "'끼다",
#  "'끼리",
#  "'나",
#  "'나'",
#  "'나가",
#  "'나누",
#  "'나다",
#  "'나라",
#  "'나쁘",
#  "'나오",
#  "'나이",
#  "'난",
#  "'난'",
#  "'날",
#  "'날'",
#  "'날짜",
#  "'남",
#  "'남'",
#  "'남다",
#  "'남자",
#  "'낫",
#  "'낮",
#  "'내",
#  "'내'",
#  "'내다",
#  "'내용",
#  "'내일",
#  "'냐",
#  "'냐'",
#  "'너",
#  "'너'",
#  "'너무",
#  "'넌",
#  "'넌'",
#  "'넘",
#  "'넘다",
#  "'넣",
#  "'넣다",
#  "'네",
#  "'네'",
#  "'녀",
#  "'녀'",
#  "'년",
#  "'년'",
#  "'노",
#  "'노'",
#  "'노가",
#  "'노력",
#  "'노무",
#  "'논",
#  "'놀",
#  "'놀다",
#  "'놈",
#  "'놈'",
#  "'높",
#  "'높다",
#  "'놓",
#  "'놓다",
#  "'뇌",
#  "'누",
#  "'누가",
#  "'누구",
#  "'눈",
#  "'눈'",
#  "'뉴",
#  "'느",
#  "'늘",
#  "'늘다",
#  "'늙",
#  "'능",
#  "'늦",
#  "'늦다",
#  "'니",
#  "'니'",
#  "'니까",
#  "'님",
#  "'님'",
#  "'다",
#  "'다'",
#  "'다녀",
#  "'다니",
#  "'다르",
#  "'다른",
#  "'다시",
#  "'다음",
#  "'다행",
#  "'단",
#  "'달",
#  "'달'",
#  "'달라",
#  "'담",
#  "'담당",
#  "'답",
#  "'답'",
#  "'당",
#  "'당'",
#  "'당연",
#  "'당장",
#  "'당하",
#  "'대",
#  "'대'",
#  "'대가",
#  "'대다",
#  "'대로",
#  "'대리",
#  "'대부",
#  "'대신",
#  "'대통",
#  "'대학",
#  "'대한",
#  "'대해",
#  "'댓",
#  "'댓글",
#  "'더",
#  "'더'",
#  "'더럽",
#  "'데",
#  "'데'",
#  "'도",
#  "'도'",
#  "'도착",
#  "'독",
#  "'돈",
#  "'돈'",
#  "'돌",
#  "'돌아",
#  "'동",
#  "'동네",
#  "'동아",
#  "'동안",
#  "'돼",
#  "'돼다",
#  "'되",
#  "'되게",
#  "'되다",
#  "'되어",
#  "'두",
#  "'두'",
#  "'두다",
#  "'둘",
#  "'둘'",
#  "'뒤",
#  "'뒤'",
#  "'뒤지",
#  "'뒷",
#  "'드",
#  "'드라",
#  "'드리",
#  "'드릴",
#  "'든",
#  "'든'",
#  "'듣",
#  "'듣다",
#  "'들",
#  "'들다",
#  "'들어",
#  "'들이",
#  "'듯",
#  "'듯'",
#  "'등",
#  "'등급",
#  "'디",
#  "'디자",
#  "'따",
#  "'따다",
#  "'따로",
#  "'따르",
#  "'딱",
#  "'딱'",
#  "'딸",
#  "'딸'",
#  "'때",
#  "'때'",
#  "'때문",
#  "'땐",
#  "'떠",
#  "'떨",
#  "'떨어",
#  "'또",
#  "'또'",
#  "'똑",
#  "'똑같",
#  "'똥",
#  "'똥'",
#  "'뛰",
#  "'뜨",
#  "'뜨다",
#  "'라",
#  "'라'",
#  "'라고",
#  "'라는",
#  "'라도",
#  "'라면",
#  "'라서",
#  "'라이",
#  "'랑",
#  "'랑'",
#  "'래",
#  "'래'",
#  "'러",
#  "'러시",
#  "'레",
#  "'로",
#  "'로'",
#  "'를",
#  "'를'",
#  "'리",
#  "'마",
#  "'마다",
#  "'마무",
#  "'마음",
#  "'마케",
#  "'막",
#  "'만",
#  "'만'",
#  "'만나",
#  "'만들",
#  "'많",
#  "'많다",
#  "'많이",
#  "'말",
#  "'말'",
#  "'말고",
#  "'말다",
#  "'말씀",
#  "'맘",
#  "'맛",
#  "'맛있",
#  "'망",
#  "'망하",
#  "'맞",
#  "'맞다",
#  "'맞추",
#  "'맡",
#  "'맡다",
#  "'매",
#  "'매우",
#  "'매일",
#  "'매출",
#  "'맨",
#  "'머",
#  "'머'",
#  "'머리",
#  "'먹",
#  "'먹다",
#  "'먼",
#  "'먼저",
#  "'멀",
#  "'멋",
#  "'멍",
#  "'메",
#  "'메뉴",
#  "'메일",
#  "'며",
#  "'면",
#  "'면'",
#  "'명",
#  "'명'",
#  "'몇",
#  "'몇'",
#  "'모",
#  "'모'",
#  "'모두",
#  "'모든",
#  "'모르",
#  "'목",
#  "'몰",
#  "'몸",
#  "'몸'",
#  "'못",
#  "'못'",
#  "'무",
#  "'무슨",
#  "'무식",
#  "'무엇",
#  "'묵",
#  "'문",
#  "'문'",
#  "'문재",
#  "'문제",
#  "'문화",
#  "'물",
#  "'물'",
#  "'물론",
#  "'물어",
#  "'뭐",
#  "'뭐'",
#  "'뭔",
#  "'뭔'",
#  "'뭔가",
#  "'뭘",
#  "'뭘'",
#  "'미",
#  "'미국",
#  "'미리",
#  "'미치",
#  "'미팅",
#  "'민",
#  "'믿",
#  "'믿다",
#  "'밀",
#  "'밉",
#  "'밉다",
#  "'바",
#  "'바꾸",
#  "'바라",
#  ...]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression

# KFold & StratifiedKFold의 객체 선언
kf = KFold(n_splits=10)
skfold = StratifiedKFold(n_splits=10)

# LogisticRegression의 객체 선언
# lgs = LogisticRegression(class_weight = 'balanced', random_state=13)
lgs = LogisticRegression(multi_class='multinomial', class_weight = 'balanced', random_state=13)

# %%
from sklearn.model_selection import cross_val_score

lg_tf_acc = cross_val_score(lgs, X_tf, y_train, scoring=None, cv=skfold)
lg_cv_acc = cross_val_score(lgs, X_cv, y_train, scoring=None, cv=skfold)

# %%
print("StratifiedKFold :: TF Acc : ", np.mean(lg_tf_acc), ", CV Acc : ", np.mean(lg_cv_acc))
# Out:
# StratifiedKFold :: TF Acc :  0.9644652839070315 , CV Acc :  0.9428752574286554

# %%
from sklearn.model_selection import cross_validate

cross_validate(lgs, X_tf, y_train, scoring=None, cv=skfold, return_train_score=True)
# Out:
# {'fit_time': array([0.33716416, 0.39036608, 0.4361999 , 0.33490133, 0.32593608,
#         0.46288252, 0.44714999, 0.51864028, 0.46286583, 0.43544888]),
#  'score_time': array([0.        , 0.        , 0.00099754, 0.00102687, 0.00099754,
#         0.        , 0.        , 0.        , 0.00099754, 0.        ]),
#  'test_score': array([0.98545455, 0.97090909, 0.97575758, 0.92242424, 0.95151515,
#         0.96480583, 0.97936893, 0.96966019, 0.96359223, 0.96116505]),
#  'train_score': array([0.9861186 , 0.9861186 , 0.98692722, 0.98800539, 0.98706199,
#         0.98598572, 0.98638997, 0.98638997, 0.98760275, 0.98665948])}

# %%
lgs.fit(X_tf, y_train)
test_tf = vec_tf.transform(test_data['comments'])
pred_test = lgs.predict(test_tf)
test_data['label'] = pred_test
print("Accuracy: %f" %lgs.score(y_test_np, pred_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-454eb2f70b8f> in <module>
#       3 pred_test = lgs.predict(test_tf)
#       4 test_data['label'] = pred_test
# ----> 5 print("Accuracy: %f" %lgs.score(y_test_np, pred_test))
#
# c:\users\gksdb\anaconda3\envs\ilovenlp\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     498         """
#     499         from .metrics import accuracy_score
# --> 500         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     501
#     502     def _more_tags(self):
#
# c:\users\gksdb\anaconda3\envs\ilovenlp\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# c:\users\gksdb\anaconda3\envs\ilovenlp\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     282         check_is_fitted(self)
#     283
# --> 284         X = check_array(X, accept_sparse='csr')
#     285
#     286         n_features = self.coef_.shape[1]
#
# c:\users\gksdb\anaconda3\envs\ilovenlp\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\gksdb\anaconda3\envs\ilovenlp\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#     697                     "your data has a single feature or array.reshape(1, -1) "
# --> 698                     "if it contains a single sample.".format(array))
#     699
#     700         # make sure we actually converted to numeric:
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1 1 1 ... 0 0 0].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
test_data.to_csv('211106_test.csv', index=False, encoding='cp949')
